# %% [markdown]
# # Influencer Score

# %%
import boto
import boto3
from boto.s3.key import Key
import boto.s3.connection

AWS_ACCESS_KEY_ID = "xxx"
AWS_SECRET_ACCESS_KEY = "xxx"
Bucketname = "project4capstones3"


conn = boto.s3.connect_to_region('us-east-1',
       aws_access_key_id=AWS_ACCESS_KEY_ID,
       aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
       is_secure=True,               # uncomment if you are not using ssl
       calling_format = boto.s3.connection.OrdinaryCallingFormat(),
       )
bucket = conn.get_bucket(Bucketname)

# %%
client = boto3.client('s3')

path = []
for key in bucket.list():
    path.append(key.name.encode('utf-8'))

# %%
content_ = []
for i in path[0:1]:
    file_ = client.get_object(Bucket = Bucketname, Key = i)
    content_.append(file_["Body"].read())

# %%
content_
# Out:
# ['{"status_num_mentions": "1", "rt_status_geo": "None", "rt_status_users_time_zone": "None", "status_geo": "None", "rt_status_favorited": "None", "rt_status_users_statuses_count": "None", "rt_status_retweeted": "None", "status_retweet_count": "0", "rt_status_source": "None", "rt_status_favorite_count": "None", "rt_status_retweet_count": "None", "rt_status_users_screen_name": "None", "status_retweeted": false, "rt_status_created_at": "None", "user_id": "20793637", "rt_status_users_favourites_count": "None", "rt_status_users_id": "None", "user_screen_name": "ScribeMarjie", "status_id": "874427443381186562", "rt_status_in_reply_to_user_id_str_num": "None", "rt_status_entities_hashtags": [], "rt_status_users_verified": "None", "rt_status_entities_user_mentions": [], "status_created_at": "Tue Jun 13 00:45:23 +0000 2017", "status_in_reply_to_status_id_num": "None", "rt_status_truncated": "None", "user_name": "Marjie Gowdy", "rt_status_users_listed_count": "None", "status_in_reply_to_user_i
# ...

# %%
# s3 = boto3.resource('s3')
# s3.Bucket('project4capstones3').download_file('2017/06/13/00/project4_capstone_stream_3-4-2017-06-13-00-45-23-b37fb9cd-75c5-4450-a5b8-3d9d106058ec','file.data')

# %%
# for key in bucket.list():
#     print key.name.encode('utf-8')

# for i in path:
#     RDD = sc.textFile('s3://' + i)
#     print RDD
    
# data = RDD.map(lambda x: json.loads(x))

# %%
# client = boto3.client('s3')

# client = boto3.client('s3')
# client.list_buckets()

# d = client.get_object(Bucket = Bucketname, Key = '2017/06/13/00/project4_capstone_stream_3-4-2017-06-13-00-45-23-b37fb9cd-75c5-4450-a5b8-3d9d106058ec')
# d["Body"].read()

# %%
ACCESS_KEY = "AKIAI3V4KTCTOD4CF7IQ"
SECRET_KEY = "Rtz/fw+eFn83ZdtG4k3HE70eLlFGi3Ghc+vLVfvP".replace("/", "%2F")

# %%
text = sc.textFile("http://s3.amazonaws.com/project4capstones3/2017/06/16/14/project4_capstone_stream_3-4-2017-06-16-14-22-55-5ea62dec-a6d7-44d9-a4d3-1ca10cddcd49")

# %%
textRDD = sc.hadoopFile('s3n://project4capstones3/2017/06/16/14/project4_capstone_stream_3-4-2017-06-16-14-22-55-5ea62dec-a6d7-44d9-a4d3-1ca10cddcd49',
                        'org.apache.hadoop.mapred.TextInputFormat',
                        'org.apache.hadoop.io.Text',
                        'org.apache.hadoop.io.LongWritable',
                       conf = {'fs.s3n.awsAccessKeyID': 'AKIAI3V4KTCTOD4CF7IQ',
                               'fs.s3n.awsSecretAccessKey':'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',})
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-20-3da01d0b6a4f> in <module>()
#       4                         'org.apache.hadoop.io.LongWritable',
#       5                        conf = {'fs.s3n.awsAccessKeyID': 'AKIAI3V4KTCTOD4CF7IQ',
# ----> 6                                'fs.s3n.awsSecretAccessKey':'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',})
#
# /Users/yogadude/spark-2.1.1-bin-hadoop2.7/python/pyspark/context.pyc in hadoopFile(self, path, inputFormatClass, keyClass, valueClass, keyConverter, valueConverter, conf, batchSize)
#     706         jrdd = self._jvm.PythonRDD.hadoopFile(self._jsc, path, inputFormatClass, keyClass,
#     707                                               valueClass, keyConverter, valueConverter,
# --> 708                                               jconf, batchSize)
#     709         return RDD(jrdd, self)
#     710
#
# ...
